# %%
N = ord("A") % 3 + 1,
print(N)
# Out:
# (3,)

# %%
import csv
import numpy as np

def FileColumn(file, column):
    with open(file, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        column_index = header.index(column)
        column_values = np.array(list(reader))[:, column_index]

    return column_values
Destroyed_APC = FileColumn('russia_losses_equipment.csv', 'APC')
print(Destroyed_APC)
# Out:
# ['516' '706' '706' '816' '846' '862' '900' '939' '945' '985' '999' '1036'
#  '1070' '1105' '1165' '1205' '1226' '1249' '1279' '1375' '1435' '1448'
#  '1470' '1487' '1535' '1556' '1578' '1597' '1625' '1640' '1664' '1694'
#  '1710' '1723' '1735' '1751' '1776' '1830' '1844' '1858' '1861' '1891'
#  '1891' '1895' '1911' '1923' '1946' '1964' '1968' '1976' '1982' '2002'
#  '2041' '2063' '2087' '2118' '2162' '2205' '2238' '2258' '2308' '2342'
#  '2389' '2418' '2445' '2471' '2519' '2567' '2610' '2651' '2686' '2713'
#  '2741' '2764' '2808' '2856' '2873' '2900' '2934' '2958' '2974' '3009'
#  '3043' '3063' '3090' '3116' '3141' '3166' '3194' '3213' '3235' '3246'
#  '3258' '3270' '3282' '3302' '3343' '3354' '3366' '3379' '3392' '3400'
#  '3416' '3429' '3438' '3450' '3466' '3484' '3492' '3503' '3528' '3545'
#  '3563' '3573' '3577' '3588' '3606' '3614' '3632' '3637' '3645' '3659'
#  '3687' '3704' '3720' '3726' '3736' '3737' '3744' '3744' '3772' '3789'
# ...

# %%
import csv
import numpy as np

def FileColumn(file, column):
    with open(file, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        column_index = header.index(column)
        column_values = np.array(list(reader))[:, column_index]

    return column_values
Destroyed_APC = FileColumn('russia_losses_equipment.csv', 'APC')

Destroyed_APC = Destroyed_APC.astype(int)
Destroyed_daily_APC = np.concatenate(([Destroyed_APC[0]], np.diff(Destroyed_APC)))
print(Destroyed_daily_APC)
# Out:
# [516 190   0 110  30  16  38  39   6  40  14  37  34  35  60  40  21  23
#   30  96  60  13  22  17  48  21  22  19  28  15  24  30  16  13  12  16
#   25  54  14  14   3  30   0   4  16  12  23  18   4   8   6  20  39  22
#   24  31  44  43  33  20  50  34  47  29  27  26  48  48  43  41  35  27
#   28  23  44  48  17  27  34  24  16  35  34  20  27  26  25  25  28  19
#   22  11  12  12  12  20  41  11  12  13  13   8  16  13   9  12  16  18
#    8  11  25  17  18  10   4  11  18   8  18   5   8  14  28  17  16   6
#   10   1   7   0  28  17   8  14   4   8   5   1   3   0  34   8   5   7
#    6  13   7   8   9  13   8   9  12   8   8   8   9   7   3   8   4   6
#   19   4  15   6  10  14   8   7  11  15  11  10  17  16  17  12   6   8
#    5   2   6   3   3  12  25  18  33  21  37  27  29  25  36  37  18   9
#   33  23  22   3  17   8  11  17   2   4  24  28  20  11  25  25  24   8
#   20  23  17  26  16  27  20  26  29  18  22  16  13  19 -14   5   7  14
# ...

# %%
import csv
import numpy as np
from heapq import nlargest


def FileColumn(file, column):
    with open(file, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        column_index = header.index(column)
        column_values = np.array(list(reader))[:, column_index]

    return column_values
Destroyed_APC = FileColumn('russia_losses_equipment.csv', 'APC')

Destroyed_APC = Destroyed_APC.astype(int)
Destroyed_daily_APC = np.concatenate(([Destroyed_APC[0]], np.diff(Destroyed_APC)))
Destroyed_daily_APC_TOP_5= nlargest(5,Destroyed_daily_APC)
print(Destroyed_daily_APC_TOP_5)
# Out:
# [516, 190, 120, 110, 96]

# %%
import csv
import numpy as np



def FileColumn(file, column):
    with open(file, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        column_index = header.index(column)
        column_values = np.array(list(reader))[:, column_index]

    return column_values
Destroyed_APC = FileColumn('russia_losses_equipment.csv', 'APC')

Destroyed_APC = Destroyed_APC.astype(int)
Destroyed_APC_1 = Destroyed_APC[98]#день№100
Destroyed_APC_2 = Destroyed_APC[498]#день№500
Destroyed_APC_in100to500= (Destroyed_APC_2-Destroyed_APC_1)/400
print(Destroyed_APC_in100to500 )
# Out:
# 11.4675

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

def FileColumn(file, column):
    with open(file, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile)
        header = next(reader)
        column_index = header.index(column)
        column_values = np.array(list(reader))[:, column_index]

    return column_values

Destroyed_APC = readTheColumn('russia_losses_equipment.csv', 'APC')
Destroyed_APC = Destroyed_APC.astype(int)
Destroyed_daily_APC = np.concatenate(([Destroyed_APC[0]], np.diff(Destroyed_APC)))

plt.figure(figsize=(8, 16), dpi=100)
plt.plot(np.arange(433, 633), Destroyed_daily_APC[np.arange(433, 633)], label='Destroyed_APC', linestyle='--', marker='.', color='red')
plt.grid(True, linestyle='--', color='gray')  
plt.xticks(fontsize=10, rotation=90)
plt.yticks(fontsize=10)
plt.xlabel('War Day')
plt.ylabel('Destroyed APC')
plt.title('ruzzian nazis APC casualties')
plt.legend()
plt.savefig('DestroyedAPC.png', dpi=100, bbox_inches='tight')

plt.show()
